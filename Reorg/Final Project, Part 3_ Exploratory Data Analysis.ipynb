# %%
import numpy as np
import pandas as pd
from sklearn import cross_validation
from sklearn import neighbors
from sklearn import grid_search
from sklearn import metrics
from sklearn import linear_model
from __future__ import division
import statsmodels.api as sm
import pylab as pl

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid", font_scale=1)
# %matplotlib inline

# %%
df = pd.read_csv("./data/ACS_2014.csv")

# %%
df.head()
# Out:
#            GEO.id GEO.id2            GEO.display-label POPGROUP.id  \
# 0              Id     Id2                    Geography          Id
# 1  0500000US01073   01073    Jefferson County, Alabama         002
# 2  0500000US01073   01073    Jefferson County, Alabama         004
# 3  0500000US10003   10003  New Castle County, Delaware         002
# 4  0500000US10003   10003  New Castle County, Delaware         004
#
#             POPGROUP.display-label  \
# 0                 Population Group
# 1                      White alone
# 2  Black or African American alone
# 3                      White alone
# 4  Black or African American alone
#
#                                             EST_VC03  \
# 0  Estimate; TOTAL NUMBER OF RACES REPORTED - Tot...
# 1                                             346240
# 2                                             277340
# 3                                             356714
# 4                                             135575
#
#                                             MOE_VC03  \
# 0  Margin of Error; TOTAL NUMBER OF RACES REPORTE...
# 1                                               2366
# 2                                               2834
# 3                                               3174
# 4                                               2480
#
#                                             EST_VC04  \
# 0  Estimate; TOTAL NUMBER OF RACES REPORTED - Tot...
# 1                                              100.0
# 2                                              100.0
# 3                                              100.0
# 4                                              100.0
#
#                                             MOE_VC04  \
# 0  Margin of Error; TOTAL NUMBER OF RACES REPORTE...
# 1                                                0.1
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#                                             EST_VC05  \
# 0  Estimate; TOTAL NUMBER OF RACES REPORTED - Tot...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                            EST_VC456  \
# 0  Estimate; GROSS RENT - Occupied units paying rent
# 1                                              35631
# 2                                              53088
# 3                                              31750
# 4                                              23405
#
#                                            MOE_VC456  \
# 0  Margin of Error; GROSS RENT - Occupied units p...
# 1                                               2450
# 2                                               3091
# 3                                               2371
# 4                                               2265
#
#                                            EST_VC457  \
# 0  Estimate; GROSS RENT - Occupied units paying r...
# 1                                                889
# 2                                                768
# 3                                               1085
# 4                                                958
#
#                                            MOE_VC457  \
# 0  Margin of Error; GROSS RENT - Occupied units p...
# 1                                                 31
# 2                                                 32
# 3                                                 38
# 4                                                 33
#
#                                            EST_VC461  \
# 0  Estimate; COMPUTERS AND INTERNET USE - Total h...
# 1                                             143964
# 2                                             108022
# 3                                             137624
# 4                                              48094
#
#                                            MOE_VC461  \
# 0  Margin of Error; COMPUTERS AND INTERNET USE - ...
# 1                                               2693
# 2                                               3044
# 3                                               2286
# 4                                               2478
#
#                                            EST_VC462  \
# 0  Estimate; COMPUTERS AND INTERNET USE - Total h...
# 1                                               84.8
# 2                                               77.1
# 3                                               87.2
# 4                                               77.7
#
#                                            MOE_VC462  \
# 0  Margin of Error; COMPUTERS AND INTERNET USE - ...
# 1                                                1.5
# 2                                                1.9
# 3                                                1.4
# 4                                                3.0
#
#                                            EST_VC463  \
# 0  Estimate; COMPUTERS AND INTERNET USE - Total h...
# 1                                               74.0
# 2                                               60.5
# 3                                               80.1
# 4                                               63.4
#
#                                            MOE_VC463
# 0  Margin of Error; COMPUTERS AND INTERNET USE - ...
# 1                                                2.1
# 2                                                2.3
# 3                                                1.9
# 4                                                4.1
#
# [5 rows x 619 columns]

# %%
df.describe()
# Out:
#                 GEO.id GEO.id2         GEO.display-label POPGROUP.id  \
# count              100     100                       100         100
# unique              44      44                        44           5
# top     0500000US13135   48201  Gwinnett County, Georgia         002
# freq                 4       4                         4          43
#
#        POPGROUP.display-label EST_VC03 MOE_VC03 EST_VC04 MOE_VC04 EST_VC05  \
# count                     100      100      100      100      100      100
# unique                      5      100      100        2        4        2
# top               White alone    90041     2535    100.0      0.1      (X)
# freq                       43        1        1       99       80       99
#
#           ...    EST_VC456 MOE_VC456 EST_VC457 MOE_VC457 EST_VC461 MOE_VC461  \
# count     ...          100       100       100       100       100       100
# unique    ...           99        99        92        50       100        97
# top       ...        39745      3965       951        26    496326      2639
# freq      ...            2         2         3         8         1         2
#
#        EST_VC462 MOE_VC462 EST_VC463 MOE_VC463
# count        100       100       100       100
# unique        90        38        91        44
# top         85.9       0.9      80.5       1.9
# freq           3         8         3        10
#
# [4 rows x 619 columns]

# %%
df.drop([])
# Out:
# Series([], dtype: float64)
